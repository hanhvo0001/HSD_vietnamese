# %% [markdown]
# <a href="https://colab.research.google.com/github/davione112/HateSpeechDetection/blob/main/Hate_speech_detection_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Library

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Making sure our results are reproducible
seed = 1
from numpy.random import seed
seed(1)
import tensorflow as tf
tf.random.set_seed(1)

# %%
import pandas as pd 
import numpy as np 
import re
import pickle
import tensorflow as tf
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Dense, Input, Bidirectional, LSTM, GRU, GlobalMaxPooling1D, GlobalAveragePooling1D, concatenate, SpatialDropout1D, Embedding, Reshape, Flatten, Dropout, Concatenate
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from keras.models import Model
from keras import backend as K
from tensorflow.keras.utils import to_categorical
from keras.preprocessing import text, sequence
from sklearn.metrics import f1_score, confusion_matrix, accuracy_score,classification_report
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit
# %cd /content/drive/MyDrive/hate_speech_detection
# Out:
# /content/drive/MyDrive/hate_speech_detection

# %%
train = pd.read_excel("preprocessed_data/train.xlsx")
dev= pd.read_excel("preprocessed_data/dev.xlsx")
test= pd.read_excel("preprocessed_data/test.xlsx")

# %% [markdown]
# ##Bi-GRU

# %% [markdown]
# ##PhoW2V

# %% [markdown]
# ###Load word embedding

# %%
EMBEDDING_FILE = 'embedding/word2vec_vi_words_300dims.txt'
MODEL_FILE = 'save_model/LSTM_model_PhoW2V.h5'
embeddings_index = {}
with open(EMBEDDING_FILE, encoding='utf8') as f:
    for line in f:
        values = line.rstrip().rsplit(' ')
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs

# %% [markdown]
# ###model

# %%
X_train = train['free_text']
y_train = train['label_id'].values

X_dev = dev['free_text']
y_dev = dev['label_id'].values

X_test = test['free_text']
y_test = test['label_id'].values
X_train = X_train.fillna('NaN')
X_dev = X_dev.fillna('NaN')
X_test = X_test.fillna('NaN')
from tensorflow.keras.utils import to_categorical
def make_featues(X, y, tokenizer, is_one_hot_label=True):
    X = tokenizer.texts_to_sequences(X)
    X = sequence.pad_sequences(X, maxlen=sequence_length)
    if is_one_hot_label: 
        y = to_categorical(y, num_classes=3)

    return X, y
seed = 1
vocabulary_size = 14000 
sequence_length = 100
embedding_dim = 300
batch_size = 256
epochs = 10
learning_rate = 1e-3
decay_rate = learning_rate / epochs

tokenizer = text.Tokenizer(lower=False,filters='!"#$%&()*+,-./:;<=>?@[\\]^`{|}~\t\n')
tokenizer.fit_on_texts(X_train)
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# --------------LOAD WORD EMBEDDING-------------------------
word_index = tokenizer.word_index
# num_words = min(vocabulary_size, len(word_index) + 1)
num_words = len(word_index) + 1
embedding_matrix = np.zeros((num_words, embedding_dim))
def scheduler(epoch, lr):
    if epoch < 3:
        return float(lr)
    else:
        return float(lr * tf.math.exp(-5.))
for word, i in word_index.items():
    if i >= vocabulary_size:
        continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector
tf.random.set_seed(seed)
X_train, y_train = make_featues(X_train, y_train, tokenizer)
X_dev, y_dev, = make_featues(X_dev, y_dev, tokenizer)
X_test, y_test, = make_featues(X_test, y_test, tokenizer, is_one_hot_label=False)
tf.random.set_seed(seed)

input = Input(shape=(sequence_length,))
x = Embedding(num_words, embedding_dim, weights=[embedding_matrix])(input)
x= SpatialDropout1D(0.4)(x)
x = LSTM(160, return_sequences=True)(x)
avg_pool = GlobalAveragePooling1D()(x)
max_pool = GlobalMaxPooling1D()(x)
conc = concatenate([avg_pool, max_pool])
tf.random.set_seed(seed)
output = Dense(3, activation="softmax")(conc)
model = Model(inputs=input, outputs=output)
tf.random.set_seed(seed)
model.summary()
tf.random.set_seed(seed)
adam = Adam(learning_rate=learning_rate, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=decay_rate)
tf.random.set_seed(seed)
my_callbacks = [
    tf.keras.callbacks.LearningRateScheduler(scheduler, verbose=1) ,       
    tf.keras.callbacks.EarlyStopping(monitor="val_loss",patience=2, restore_best_weights=True),
    tf.keras.callbacks.ModelCheckpoint('weights.{epoch:03d}-{val_loss:.4f}.hdf5', monitor='val_loss', verbose=1, save_best_only=True, mode='auto'),
    tf.keras.callbacks.TensorBoard(log_dir='./logs'),
  ]
tf.random.set_seed(seed)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
tf.random.set_seed(seed)
history = model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(X_dev, y_dev),callbacks=my_callbacks,shuffle=False)  
model.save(MODEL_FILE)
tf.random.set_seed(seed)
prediction = model.predict(X_test, batch_size=batch_size, verbose=0)
y_pred = prediction.argmax(axis=-1)
print(classification_report(y_test, y_pred, digits = 4)) 
# cf = confusion_matrix(y_test, y_pred)
# print(cf)

# df_cm = pd.DataFrame(cf, index = ["clean","offensive","hate"],
#                   columns = ["clean","offensive","hate"])
# plt.clf()
# sn.heatmap(df_cm, annot=True, cmap="Greys",fmt='g', cbar=True, annot_kws={"size": 28})
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            [(None, 100)]        0
# __________________________________________________________________________________________________
# embedding_5 (Embedding)         (None, 100, 300)     3993300     input_6[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_5 (SpatialDro (None, 100, 300)     0           embedding_5[0][0]
# __________________________________________________________________________________________________
# lstm_5 (LSTM)                   (None, 100, 160)     295040      spatial_dropout1d_5[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_5 (Glo (None, 160)          0           lstm_5[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_5 (GlobalM (None, 160)          0           lstm_5[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 320)          0           global_average_pooling1d_5[0][0]
#                                                                  global_max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 3)            963         concatenate_5[0][0]
# ==================================================================================================
# Total params: 4,289,303
# Trainable params: 4,289,303
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/10
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# 85/85 [==============================] - 9s 76ms/step - loss: 0.5953 - accuracy: 0.8168 - val_loss: 0.4406 - val_accuracy: 0.8366
#
# Epoch 00001: val_loss improved from inf to 0.44065, saving model to weights.001-0.4406.hdf5
# Epoch 2/10
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# 85/85 [==============================] - 5s 63ms/step - loss: 0.3641 - accuracy: 0.8655 - val_loss: 0.3632 - val_accuracy: 0.8596
#
# Epoch 00002: val_loss improved from 0.44065 to 0.36324, saving model to weights.002-0.3632.hdf5
# Epoch 3/10
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# 85/85 [==============================] - 5s 63ms/step - loss: 0.2868 - accuracy: 0.8943 - val_loss: 0.3652 - val_accuracy: 0.8700
#
# Epoch 00003: val_loss did not improve from 0.36324
# Epoch 4/10
#
# Epoch 00004: LearningRateScheduler setting learning rate to 6.737947387591703e-06.
# 85/85 [==============================] - 5s 65ms/step - loss: 0.2346 - accuracy: 0.9111 - val_loss: 0.3579 - val_accuracy: 0.8674
#
# Epoch 00004: val_loss improved from 0.36324 to 0.35793, saving model to weights.004-0.3579.hdf5
# Epoch 5/10
#
# Epoch 00005: LearningRateScheduler setting learning rate to 4.539993270213927e-08.
# 85/85 [==============================] - 5s 65ms/step - loss: 0.2315 - accuracy: 0.9124 - val_loss: 0.3579 - val_accuracy: 0.8674
#
# Epoch 00005: val_loss improved from 0.35793 to 0.35791, saving model to weights.005-0.3579.hdf5
# Epoch 6/10
#
# Epoch 00006: LearningRateScheduler setting learning rate to 3.0590233124350164e-10.
# 85/85 [==============================] - 5s 64ms/step - loss: 0.2327 - accuracy: 0.9133 - val_loss: 0.3579 - val_accuracy: 0.8674
#
# Epoch 00006: val_loss did not improve from 0.35791
# Epoch 7/10
#
# Epoch 00007: LearningRateScheduler setting learning rate to 2.0611537650261358e-12.
# 85/85 [==============================] - 5s 64ms/step - loss: 0.2328 - accuracy: 0.9127 - val_loss: 0.3579 - val_accuracy: 0.8674
#
# Epoch 00007: val_loss did not improve from 0.35791
#               precision    recall  f1-score   support
#
#            0     0.9094    0.9665    0.9371      5040
#            1     0.6016    0.3540    0.4457       435
#            2     0.6792    0.5453    0.6049       695
#
#     accuracy                         0.8759      6170
#    macro avg     0.7301    0.6219    0.6626      6170
# weighted avg     0.8618    0.8759    0.8650      6170

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
def plot_metric(history, metric):
    train_metrics = history.history[metric]
    val_metrics = history.history['val_'+metric]
    epochs = range(1, len(train_metrics) + 1)
    plt.plot(epochs, train_metrics, 'bo--')
    plt.plot(epochs, val_metrics, 'ro-')
    plt.title('Training and validation '+ metric)
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend(["train_"+metric, 'val_'+metric])
    plt.show()
plot_metric(history, 'loss')
plot_metric(history, 'accuracy')

# %% [markdown]
# ##FastText

# %% [markdown]
# ###Load word embedding

# %%
EMBEDDING_FILE = 'embedding/cc.vi.300.vec'
MODEL_FILE = 'save_model/LSTM_model_FasText.h5'
embeddings_index = {}
with open(EMBEDDING_FILE, encoding='utf8') as f:
    for line in f:
        values = line.rstrip().rsplit(' ')
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs

# %% [markdown]
# ###Model

# %%
X_train = train['free_text']
y_train = train['label_id'].values

X_dev = dev['free_text']
y_dev = dev['label_id'].values

X_test = test['free_text']
y_test = test['label_id'].values
from tensorflow.keras.utils import to_categorical
def make_featues(X, y, tokenizer, is_one_hot_label=True):
    X = tokenizer.texts_to_sequences(X)
    X = sequence.pad_sequences(X, maxlen=sequence_length)
    if is_one_hot_label: 
        y = to_categorical(y, num_classes=3)
    return X, y
seed = 1
vocabulary_size = 14000 
sequence_length = 100

embedding_dim = 300
batch_size = 256
epochs = 10
learning_rate = 1e-3
decay_rate = learning_rate / epochs

X_train = X_train.fillna('NaN')
X_dev = X_dev.fillna('NaN')
X_test = X_test.fillna('NaN')
tokenizer = text.Tokenizer(lower=False, filters='!"#$%&()*+,-./:;<=>?@[\\]^`{|}~\t\n')
tokenizer.fit_on_texts(X_train)
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# --------------LOAD WORD EMBEDDING-------------------------
word_index = tokenizer.word_index
# num_words = min(vocabulary_size, len(word_index) + 1)
num_words = len(word_index) + 1
embedding_matrix = np.zeros((num_words, embedding_dim))

def scheduler(epoch, lr):
    if epoch < 3:
        return float(lr)
    else:
        return float(lr * tf.math.exp(-5.))
for word, i in word_index.items():
    if i >= vocabulary_size:
        continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector
tf.random.set_seed(seed)
X_train, y_train = make_featues(X_train, y_train, tokenizer)
X_dev, y_dev, = make_featues(X_dev, y_dev, tokenizer)
X_test, y_test, = make_featues(X_test, y_test, tokenizer, is_one_hot_label=False)
tf.random.set_seed(seed)
input = Input(shape=(sequence_length,))
x = Embedding(num_words, embedding_dim, weights=[embedding_matrix])(input)
tf.random.set_seed(seed)
x= SpatialDropout1D(0.4)(x)
x = LSTM(160, return_sequences=True)(x)
tf.random.set_seed(seed)
avg_pool = GlobalAveragePooling1D()(x)
max_pool = GlobalMaxPooling1D()(x)
conc = concatenate([avg_pool, max_pool])
tf.random.set_seed(seed)
output = Dense(3, activation="softmax")(conc)
model = Model(inputs=input, outputs=output)
tf.random.set_seed(seed)
model.summary()
tf.random.set_seed(seed)
adam = Adam(learning_rate=learning_rate, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=decay_rate)
tf.random.set_seed(seed)
my_callbacks = [
    tf.keras.callbacks.LearningRateScheduler(scheduler, verbose=1) ,       
    tf.keras.callbacks.EarlyStopping(monitor="val_loss",patience=3, restore_best_weights=True),
    tf.keras.callbacks.ModelCheckpoint('weights.{epoch:03d}-{val_loss:.4f}.hdf5', monitor='val_loss', verbose=1, save_best_only=True, mode='auto'),
    tf.keras.callbacks.TensorBoard(log_dir='./logs'),
]
tf.random.set_seed(seed)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
tf.random.set_seed(seed)
history = model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(X_dev, y_dev),callbacks=my_callbacks,shuffle=False)  
model.save(MODEL_FILE)

prediction = model.predict(X_test, batch_size=batch_size, verbose=0)
y_pred = prediction.argmax(axis=-1)

cf = confusion_matrix(y_test, y_pred)
print(cf)

df_cm = pd.DataFrame(cf, index = ["clean","offensive","hate"],
                  columns = ["clean","offensive","hate"])
plt.clf()
sn.heatmap(df_cm, annot=True, cmap="Greys",fmt='g', cbar=True, annot_kws={"size": 28})
print(classification_report(y_pred, y_test, digits = 4))
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
def plot_metric(history, metric):
    train_metrics = history.history[metric]
    val_metrics = history.history['val_'+metric]
    epochs = range(1, len(train_metrics) + 1)
    plt.plot(epochs, train_metrics, 'bo--')
    plt.plot(epochs, val_metrics, 'ro-')
    plt.title('Training and validation '+ metric)
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend(["train_"+metric, 'val_'+metric])
    plt.show()
plot_metric(history, 'loss')
plot_metric(history, 'accuracy')
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            [(None, 100)]        0
# __________________________________________________________________________________________________
# embedding_7 (Embedding)         (None, 100, 300)     3993300     input_8[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_7 (SpatialDro (None, 100, 300)     0           embedding_7[0][0]
# __________________________________________________________________________________________________
# lstm_7 (LSTM)                   (None, 100, 160)     295040      spatial_dropout1d_7[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_7 (Glo (None, 160)          0           lstm_7[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_7 (GlobalM (None, 160)          0           lstm_7[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 320)          0           global_average_pooling1d_7[0][0]
#                                                                  global_max_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 3)            963         concatenate_7[0][0]
# ==================================================================================================
# Total params: 4,289,303
# Trainable params: 4,289,303
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/10
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# 85/85 [==============================] - 9s 77ms/step - loss: 0.5783 - accuracy: 0.8201 - val_loss: 0.4173 - val_accuracy: 0.8457
#
# Epoch 00001: val_loss improved from inf to 0.41734, saving model to weights.001-0.4173.hdf5
# Epoch 2/10
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# 85/85 [==============================] - 5s 64ms/step - loss: 0.3576 - accuracy: 0.8686 - val_loss: 0.3583 - val_accuracy: 0.8639
#
# Epoch 00002: val_loss improved from 0.41734 to 0.35826, saving model to weights.002-0.3583.hdf5
# Epoch 3/10
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# 85/85 [==============================] - 5s 64ms/step - loss: 0.2921 - accuracy: 0.8920 - val_loss: 0.3641 - val_accuracy: 0.8697
#
# Epoch 00003: val_loss did not improve from 0.35826
# Epoch 4/10
#
# Epoch 00004: LearningRateScheduler setting learning rate to 6.737947387591703e-06.
# 85/85 [==============================] - 5s 63ms/step - loss: 0.2441 - accuracy: 0.9089 - val_loss: 0.3570 - val_accuracy: 0.8710
#
# Epoch 00004: val_loss improved from 0.35826 to 0.35695, saving model to weights.004-0.3570.hdf5
# Epoch 5/10
#
# Epoch 00005: LearningRateScheduler setting learning rate to 4.539993270213927e-08.
# 85/85 [==============================] - 5s 64ms/step - loss: 0.2404 - accuracy: 0.9090 - val_loss: 0.3569 - val_accuracy: 0.8710
#
# Epoch 00005: val_loss improved from 0.35695 to 0.35694, saving model to weights.005-0.3569.hdf5
# Epoch 6/10
#
# Epoch 00006: LearningRateScheduler setting learning rate to 3.0590233124350164e-10.
# 85/85 [==============================] - 5s 63ms/step - loss: 0.2412 - accuracy: 0.9103 - val_loss: 0.3569 - val_accuracy: 0.8710
#
# Epoch 00006: val_loss did not improve from 0.35694
# Epoch 7/10
#
# Epoch 00007: LearningRateScheduler setting learning rate to 2.0611537650261358e-12.
# 85/85 [==============================] - 5s 65ms/step - loss: 0.2417 - accuracy: 0.9090 - val_loss: 0.3569 - val_accuracy: 0.8710
#
# Epoch 00007: val_loss did not improve from 0.35694
# Epoch 8/10
#
# Epoch 00008: LearningRateScheduler setting learning rate to 1.3887944579884983e-14.
# 85/85 [==============================] - 5s 63ms/step - loss: 0.2409 - accuracy: 0.9099 - val_loss: 0.3569 - val_accuracy: 0.8710
#
# Epoch 00008: val_loss did not improve from 0.35694
# [[4846   60  134]
#  [ 224  147   64]
#  [ 264   45  386]]
#               precision    recall  f1-score   support
#
#            0     0.9615    0.9085    0.9343      5334
#            1     0.3379    0.5833    0.4279       252
#            2     0.5554    0.6610    0.6036       584
#
#     accuracy                         0.8718      6170
#    macro avg     0.6183    0.7176    0.6553      6170
# weighted avg     0.8976    0.8718    0.8823      6170
