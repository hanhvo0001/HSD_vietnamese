# %% [markdown]
# <a href="https://colab.research.google.com/github/davione112/HateSpeechDetection/blob/main/Hate_speech_detection_Bi_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Library

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# # Making sure our results are reproducible
# seed = 1
# from numpy.random import seed
# seed(1)
# import tensorflow as tf
# tf.random.set_seed(1)

# %%
import pandas as pd 
import numpy as np 
import re
import pickle
import tensorflow as tf
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Dense, Input, Bidirectional, LSTM, GRU, GlobalMaxPooling1D, GlobalAveragePooling1D, concatenate, SpatialDropout1D, Embedding, Reshape, Flatten, Dropout, Concatenate
from keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from keras.models import Model
from keras import backend as K
from tensorflow.keras.utils import to_categorical
from keras.preprocessing import text, sequence
from sklearn.metrics import f1_score, confusion_matrix, accuracy_score,classification_report
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit
# %cd /content/drive/MyDrive/hate_speech_detection
# Out:
# /content/drive/MyDrive/hate_speech_detection

# %%
train = pd.read_excel("preprocessed_data/train.xlsx")
dev= pd.read_excel("preprocessed_data/dev.xlsx")
test= pd.read_excel("preprocessed_data/test.xlsx")

# %% [markdown]
# ##Bi-GRU

# %% [markdown]
# ##PhoW2V

# %% [markdown]
# ###Load word embedding

# %%
EMBEDDING_FILE = 'embedding/word2vec_vi_words_300dims.txt'
MODEL_FILE = 'save_model/Bi_LSTM_model_PhoW2V.h5'
embeddings_index = {}
with open(EMBEDDING_FILE, encoding='utf8') as f:
    for line in f:
        values = line.rstrip().rsplit(' ')
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs

# %% [markdown]
# ###model

# %%
X_train = train['free_text']
y_train = train['label_id'].values

X_dev = dev['free_text']
y_dev = dev['label_id'].values

X_test = test['free_text']
y_test = test['label_id'].values
from tensorflow.keras.utils import to_categorical
def make_featues(X, y, tokenizer, is_one_hot_label=True):
    X = tokenizer.texts_to_sequences(X)
    X = sequence.pad_sequences(X, maxlen=sequence_length)
    if is_one_hot_label: 
        y = to_categorical(y, num_classes=3)

    return X, y
seed = 1
vocabulary_size = 14000 
sequence_length = 100

embedding_dim = 300
batch_size = 256
epochs = 10
learning_rate = 1e-3
decay_rate = learning_rate / epochs


X_train = X_train.fillna('NaN')
X_dev = X_dev.fillna('NaN')
X_test = X_test.fillna('NaN')
tokenizer = text.Tokenizer(lower=False, filters='!"#$%&()*+,-./:;<=>?@[\\]^`{|}~\t\n')
tokenizer.fit_on_texts(X_train)
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# --------------LOAD WORD EMBEDDING-------------------------
word_index = tokenizer.word_index
# num_words = min(vocabulary_size, len(word_index) + 1)
num_words = len(word_index) + 1
embedding_matrix = np.zeros((num_words, embedding_dim))


def scheduler(epoch, lr):
    if epoch < 3:
        return float(lr)
    else:
        return float(lr * tf.math.exp(-4.))
for word, i in word_index.items():
    if i >= vocabulary_size:
        continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector
tf.random.set_seed(seed)
X_train, y_train = make_featues(X_train, y_train, tokenizer)
X_dev, y_dev, = make_featues(X_dev, y_dev, tokenizer)
X_test, y_test, = make_featues(X_test, y_test, tokenizer, is_one_hot_label=False)
tf.random.set_seed(seed)
input = Input(shape=(sequence_length,))
x = Embedding(num_words, embedding_dim, weights=[embedding_matrix])(input)
tf.random.set_seed(seed)
x= SpatialDropout1D(0.4)(x)
tf.random.set_seed(seed)
x = Bidirectional(LSTM(300, return_sequences=True, recurrent_dropout=0.01))(x)
tf.random.set_seed(seed)
x = Bidirectional(LSTM(150, return_sequences=True, recurrent_dropout=0.01))(x)
tf.random.set_seed(seed)
x = Bidirectional(LSTM(50, return_sequences=True))(x)
tf.random.set_seed(seed)
avg_pool = GlobalAveragePooling1D()(x)
max_pool = GlobalMaxPooling1D()(x)
conc = concatenate([avg_pool, max_pool])
tf.random.set_seed(seed)
output = Dense(3, activation="softmax")(conc)
model = Model(inputs=input, outputs=output)
tf.random.set_seed(seed)
model.summary()
tf.random.set_seed(seed)
adam = Adam(learning_rate=learning_rate, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=decay_rate)
tf.random.set_seed(seed)
my_callbacks = [
    tf.keras.callbacks.LearningRateScheduler(scheduler, verbose=1) ,       
    tf.keras.callbacks.EarlyStopping(monitor="val_loss",patience=2, restore_best_weights=True),
    tf.keras.callbacks.ModelCheckpoint('weights.{epoch:03d}-{val_loss:.4f}.hdf5', monitor='val_loss', verbose=1, save_best_only=True, mode='auto'),
    tf.keras.callbacks.TensorBoard(log_dir='./logs'),
]
tf.random.set_seed(seed)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
tf.random.set_seed(seed)
history = model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(X_dev, y_dev),callbacks=my_callbacks,shuffle=False)  
model.save(MODEL_FILE)
tf.random.set_seed(seed)
prediction = model.predict(X_test, batch_size=batch_size, verbose=1)
y_pred = prediction.argmax(axis=-1)

cf = confusion_matrix(y_test, y_pred)
print(cf)

df_cm = pd.DataFrame(cf, index = ["clean","offensive","hate"],
                  columns = ["clean","offensive","hate"])
plt.clf()
sn.heatmap(df_cm, annot=True, cmap="Greys",fmt='g', cbar=True, annot_kws={"size": 28})
print(classification_report(y_pred, y_test, digits = 4))
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
def plot_metric(history, metric):
    train_metrics = history.history[metric]
    val_metrics = history.history['val_'+metric]
    epochs = range(1, len(train_metrics) + 1)
    plt.plot(epochs, train_metrics, 'bo--')
    plt.plot(epochs, val_metrics, 'ro-')
    plt.title('Training and validation '+ metric)
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend(["train_"+metric, 'val_'+metric])
    plt.show()
plot_metric(history, 'loss')
plot_metric(history, 'accuracy')
# Out:
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 100)]        0
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, 100, 300)     3993300     input_5[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_4 (SpatialDro (None, 100, 300)     0           embedding_4[0][0]
# __________________________________________________________________________________________________
# bidirectional_12 (Bidirectional (None, 100, 600)     1442400     spatial_dropout1d_4[0][0]
# __________________________________________________________________________________________________
# bidirectional_13 (Bidirectional (None, 100, 300)     901200      bidirectional_12[0][0]
# __________________________________________________________________________________________________
# bidirectional_14 (Bidirectional (None, 100, 100)     140400      bidirectional_13[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_4 (Glo (None, 100)          0           bidirectional_14[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_4 (GlobalM (None, 100)          0           bidirectional_14[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 200)          0           global_average_pooling1d_4[0][0]
#                                                                  global_max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 3)            603         concatenate_4[0][0]
# ==================================================================================================
# Total params: 6,477,903
# Trainable params: 6,477,903
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/10
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# 85/85 [==============================] - 195s 2s/step - loss: 0.5441 - accuracy: 0.8225 - val_loss: 0.4085 - val_accuracy: 0.8496
#
# Epoch 00001: val_loss improved from inf to 0.40847, saving model to weights.001-0.4085.hdf5
# Epoch 2/10
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# 85/85 [==============================] - 167s 2s/step - loss: 0.3566 - accuracy: 0.8663 - val_loss: 0.3751 - val_accuracy: 0.8658
#
# Epoch 00002: val_loss improved from 0.40847 to 0.37511, saving model to weights.002-0.3751.hdf5
# Epoch 3/10
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# 85/85 [==============================] - 169s 2s/step - loss: 0.2868 - accuracy: 0.8944 - val_loss: 0.3879 - val_accuracy: 0.8661
#
# Epoch 00003: val_loss did not improve from 0.37511
# Epoch 4/10
#
# Epoch 00004: LearningRateScheduler setting learning rate to 1.831564077292569e-05.
# 85/85 [==============================] - 167s 2s/step - loss: 0.2271 - accuracy: 0.9160 - val_loss: 0.3676 - val_accuracy: 0.8710
#
# Epoch 00004: val_loss improved from 0.37511 to 0.36757, saving model to weights.004-0.3676.hdf5
# Epoch 5/10
#
# Epoch 00005: LearningRateScheduler setting learning rate to 3.35462658540564e-07.
# 85/85 [==============================] - 167s 2s/step - loss: 0.2210 - accuracy: 0.9206 - val_loss: 0.3676 - val_accuracy: 0.8710
#
# Epoch 00005: val_loss improved from 0.36757 to 0.36755, saving model to weights.005-0.3676.hdf5
# Epoch 6/10
#
# Epoch 00006: LearningRateScheduler setting learning rate to 6.144213138270516e-09.
# 85/85 [==============================] - 166s 2s/step - loss: 0.2213 - accuracy: 0.9196 - val_loss: 0.3676 - val_accuracy: 0.8710
#
# Epoch 00006: val_loss improved from 0.36755 to 0.36755, saving model to weights.006-0.3676.hdf5
# Epoch 7/10
#
# Epoch 00007: LearningRateScheduler setting learning rate to 1.1253518950038455e-10.
# 85/85 [==============================] - 167s 2s/step - loss: 0.2220 - accuracy: 0.9183 - val_loss: 0.3676 - val_accuracy: 0.8710
#
# Epoch 00007: val_loss improved from 0.36755 to 0.36755, saving model to weights.007-0.3676.hdf5
# Epoch 8/10
#
# Epoch 00008: LearningRateScheduler setting learning rate to 2.0611539818665703e-12.
# 85/85 [==============================] - 167s 2s/step - loss: 0.2212 - accuracy: 0.9195 - val_loss: 0.3676 - val_accuracy: 0.8710
#
# Epoch 00008: val_loss did not improve from 0.36755
# Epoch 9/10
#
# Epoch 00009: LearningRateScheduler setting learning rate to 3.77513538279365e-14.
# 85/85 [==============================] - 167s 2s/step - loss: 0.2206 - accuracy: 0.9188 - val_loss: 0.3676 - val_accuracy: 0.8710
#
# Epoch 00009: val_loss did not improve from 0.36755
# 25/25 [==============================] - 9s 304ms/step
# [[4833   85  122]
#  [ 202  167   66]
#  [ 242   61  392]]
#               precision    recall  f1-score   support
#
#            0     0.9589    0.9159    0.9369      5277
#            1     0.3839    0.5335    0.4465       313
#            2     0.5640    0.6759    0.6149       580
#
#     accuracy                         0.8739      6170
#    macro avg     0.6356    0.7084    0.6661      6170
# weighted avg     0.8926    0.8739    0.8818      6170

# %% [markdown]
# ##FastText

# %% [markdown]
# ###Load word embedding

# %%
EMBEDDING_FILE = 'embedding/cc.vi.300.vec'
MODEL_FILE = 'save_model/Bi_LSTM_model_FastText.h5'
embeddings_index = {}
with open(EMBEDDING_FILE, encoding='utf8') as f:
    for line in f:
        values = line.rstrip().rsplit(' ')
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs

# %% [markdown]
# ###Model

# %%
X_train = train['free_text']
y_train = train['label_id'].values

X_dev = dev['free_text']
y_dev = dev['label_id'].values

X_test = test['free_text']
y_test = test['label_id'].values
from tensorflow.keras.utils import to_categorical
def make_featues(X, y, tokenizer, is_one_hot_label=True):
    X = tokenizer.texts_to_sequences(X)
    X = sequence.pad_sequences(X, maxlen=sequence_length)
    if is_one_hot_label: 
        y = to_categorical(y, num_classes=3)

    return X, y
seed = 1
vocabulary_size = 14000 
sequence_length = 100

embedding_dim = 300
batch_size = 256
epochs = 10
learning_rate = 1e-3
decay_rate = learning_rate / epochs


X_train = X_train.fillna('NaN')
X_dev = X_dev.fillna('NaN')
X_test = X_test.fillna('NaN')
tokenizer = text.Tokenizer(lower=False, filters='!"#$%&()*+,-./:;<=>?@[\\]^`{|}~\t\n')
tokenizer.fit_on_texts(X_train)
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# --------------LOAD WORD EMBEDDING-------------------------
word_index = tokenizer.word_index
# num_words = min(vocabulary_size, len(word_index) + 1)
num_words = len(word_index) + 1
embedding_matrix = np.zeros((num_words, embedding_dim))


def scheduler(epoch, lr):
    if epoch < 3:
        return float(lr)
    else:
        return float(lr * tf.math.exp(-5.))
for word, i in word_index.items():
    if i >= vocabulary_size:
        continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector
tf.random.set_seed(seed)
X_train, y_train = make_featues(X_train, y_train, tokenizer)
X_dev, y_dev, = make_featues(X_dev, y_dev, tokenizer)
X_test, y_test, = make_featues(X_test, y_test, tokenizer, is_one_hot_label=False)
tf.random.set_seed(seed)
input = Input(shape=(sequence_length,))
x = Embedding(num_words, embedding_dim, weights=[embedding_matrix])(input)
tf.random.set_seed(seed)
x= SpatialDropout1D(0.5)(x)
tf.random.set_seed(seed)
x = Bidirectional(LSTM(150, return_sequences=True))(x)
tf.random.set_seed(seed)
x = Bidirectional(LSTM(50, return_sequences=True))(x)
tf.random.set_seed(seed)
avg_pool = GlobalAveragePooling1D()(x)
max_pool = GlobalMaxPooling1D()(x)
conc = concatenate([avg_pool, max_pool])
tf.random.set_seed(seed)

output = Dense(3, activation="softmax")(conc)
model = Model(inputs=input, outputs=output)
tf.random.set_seed(seed)
model.summary()
tf.random.set_seed(seed)
adam = Adam(learning_rate=learning_rate, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=decay_rate)
tf.random.set_seed(seed)
my_callbacks = [
    tf.keras.callbacks.LearningRateScheduler(scheduler, verbose=1) ,       
    tf.keras.callbacks.EarlyStopping(monitor="val_loss",patience=2, restore_best_weights=True),
    tf.keras.callbacks.ModelCheckpoint('weights.{epoch:03d}-{val_loss:.4f}.hdf5', monitor='val_loss', verbose=1, save_best_only=True, mode='auto'),
    tf.keras.callbacks.TensorBoard(log_dir='./logs'),
]
tf.random.set_seed(seed)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
tf.random.set_seed(seed)
history = model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(X_dev, y_dev),callbacks=my_callbacks,shuffle=False)  
model.save(MODEL_FILE)
tf.random.set_seed(seed)
prediction = model.predict(X_test, batch_size=batch_size, verbose=0)
y_pred = prediction.argmax(axis=-1)

cf = confusion_matrix(y_test, y_pred)
print(cf)

df_cm = pd.DataFrame(cf, index = ["clean","offensive","hate"],
                  columns = ["clean","offensive","hate"])
plt.clf()
sn.heatmap(df_cm, annot=True, cmap="Greys",fmt='g', cbar=True, annot_kws={"size": 28})
print(classification_report(y_pred, y_test, digits = 4))
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
def plot_metric(history, metric):
    train_metrics = history.history[metric]
    val_metrics = history.history['val_'+metric]
    epochs = range(1, len(train_metrics) + 1)
    plt.plot(epochs, train_metrics, 'bo--')
    plt.plot(epochs, val_metrics, 'ro-')
    plt.title('Training and validation '+ metric)
    plt.xlabel("Epochs")
    plt.ylabel(metric)
    plt.legend(["train_"+metric, 'val_'+metric])
    plt.show()
plot_metric(history, 'loss')
plot_metric(history, 'accuracy')
# Out:
# Model: "model_9"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_10 (InputLayer)           [(None, 100)]        0
# __________________________________________________________________________________________________
# embedding_9 (Embedding)         (None, 100, 300)     3993300     input_10[0][0]
# __________________________________________________________________________________________________
# spatial_dropout1d_9 (SpatialDro (None, 100, 300)     0           embedding_9[0][0]
# __________________________________________________________________________________________________
# bidirectional_17 (Bidirectional (None, 100, 300)     541200      spatial_dropout1d_9[0][0]
# __________________________________________________________________________________________________
# bidirectional_18 (Bidirectional (None, 100, 100)     140400      bidirectional_17[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_9 (Glo (None, 100)          0           bidirectional_18[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_9 (GlobalM (None, 100)          0           bidirectional_18[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 200)          0           global_average_pooling1d_9[0][0]
#                                                                  global_max_pooling1d_9[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 3)            603         concatenate_9[0][0]
# ==================================================================================================
# Total params: 4,675,503
# Trainable params: 4,675,503
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/10
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# 85/85 [==============================] - 25s 211ms/step - loss: 0.5373 - accuracy: 0.8277 - val_loss: 0.4037 - val_accuracy: 0.8483
#
# Epoch 00001: val_loss improved from inf to 0.40374, saving model to weights.001-0.4037.hdf5
# Epoch 2/10
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# 85/85 [==============================] - 15s 181ms/step - loss: 0.3547 - accuracy: 0.8682 - val_loss: 0.3648 - val_accuracy: 0.8635
#
# Epoch 00002: val_loss improved from 0.40374 to 0.36478, saving model to weights.002-0.3648.hdf5
# Epoch 3/10
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# 85/85 [==============================] - 15s 174ms/step - loss: 0.2953 - accuracy: 0.8901 - val_loss: 0.3711 - val_accuracy: 0.8690
#
# Epoch 00003: val_loss did not improve from 0.36478
# Epoch 4/10
#
# Epoch 00004: LearningRateScheduler setting learning rate to 6.737947387591703e-06.
# 85/85 [==============================] - 15s 181ms/step - loss: 0.2474 - accuracy: 0.9072 - val_loss: 0.3611 - val_accuracy: 0.8684
#
# Epoch 00004: val_loss improved from 0.36478 to 0.36112, saving model to weights.004-0.3611.hdf5
# Epoch 5/10
#
# Epoch 00005: LearningRateScheduler setting learning rate to 4.539993270213927e-08.
# 85/85 [==============================] - 15s 182ms/step - loss: 0.2451 - accuracy: 0.9080 - val_loss: 0.3611 - val_accuracy: 0.8684
#
# Epoch 00005: val_loss improved from 0.36112 to 0.36111, saving model to weights.005-0.3611.hdf5
# Epoch 6/10
#
# Epoch 00006: LearningRateScheduler setting learning rate to 3.0590233124350164e-10.
# 85/85 [==============================] - 15s 182ms/step - loss: 0.2452 - accuracy: 0.9093 - val_loss: 0.3611 - val_accuracy: 0.8684
#
# Epoch 00006: val_loss did not improve from 0.36111
# Epoch 7/10
#
# Epoch 00007: LearningRateScheduler setting learning rate to 2.0611537650261358e-12.
# 85/85 [==============================] - 15s 182ms/step - loss: 0.2449 - accuracy: 0.9099 - val_loss: 0.3611 - val_accuracy: 0.8684
#
# Epoch 00007: val_loss did not improve from 0.36111
# [[4836   85  119]
#  [ 195  166   74]
#  [ 264   58  373]]
#               precision    recall  f1-score   support
#
#            0     0.9595    0.9133    0.9358      5295
#            1     0.3816    0.5372    0.4462       309
#            2     0.5367    0.6590    0.5916       566
#
#     accuracy                         0.8712      6170
#    macro avg     0.6259    0.7032    0.6579      6170
# weighted avg     0.8918    0.8712    0.8797      6170
